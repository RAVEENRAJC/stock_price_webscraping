# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
API_KEY = 'FIU1XDNGDGHAKV30'
symbol = 'AAPL'
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={API_KEY}&outputsize=compact'
response = requests.get(url)
data = response.json()

# %%
# Parse JSON
daily_data = data['Time Series (Daily)']
df = pd.DataFrame(daily_data).T
df.index = pd.to_datetime(df.index)
df = df.astype(float)

# %%
df['4. close'].plot(figsize=(10, 5), title=f'{symbol} Closing Prices')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.grid()
plt.show()

# %%
df.head()
df.to_csv("closing_price.csv",index=False)
